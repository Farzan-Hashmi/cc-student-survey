# %% [markdown]
# # Importing required libraries
#
# - **Bamboolib** is a free library that gives pandas a GUI interface. It makes it very easy to get graphs and manipulate the rows and columns of the data frame
#
# - **pandas** is the most popular data frame library in python. it just makes it easy to store and manipulate data

# %%
import bamboolib as bam
import pandas as pd

# %% [markdown]
# # Getting the data from the google sheet
#
# - the following block of code just reads the data from the google sheets where the survey data is going to.(https://docs.google.com/spreadsheets/d/12ojjnk25qPNqnhrhIPjBmfLIDbD3aoynV7emSwuaK7Y/edit#gid=324197163)

# %%
gsheetid = "12ojjnk25qPNqnhrhIPjBmfLIDbD3aoynV7emSwuaK7Y"
sheet_name = "data"
gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)
df = pd.read_csv(gsheet_url)

# %% [markdown]
# ### Dropping Unncessary Columns

# %%
df = df.drop(columns=['Timestamp']) #The Timestamp column really is not needed in our study

# %% [markdown]
# # Looking at relationships between the data
#
# - bamboolib has a function patterns() which shows the predictive powet score of all the variables. Think of it as a better version of coerrelation. We will still use a coerrelation matrix later on though

# %%
bam.patterns(df)

# %% [markdown]
# ## Observing the relationship between 'in person?' and 'more_distracted_at_home?'

# %%
bam.plot(df, 'in person?', 'more_distracted_at_home?')
# Out:
# TabSection(children=(BrowserCheck(), HBox(children=(Tab(closable=False, title='plot', _dom_classes=('bamboolib…

# %%
df['in person?_label'] = df['in person?'].factorize(sort=False, na_sentinel=-1)[0]
df['major_label'] = df['major'].factorize(sort=False, na_sentinel=-1)[0]
df['labs?_label'] = df['labs?'].factorize(sort=False, na_sentinel=-1)[0]
df['easy_internet?_label'] = df['easy_internet?'].factorize(sort=False, na_sentinel=-1)[0]
df['more_distracted_at_home?_label'] = df['more_distracted_at_home?'].factorize(sort=False, na_sentinel=-1)[0]

# %%
bam.correlations(df)
# Out:
# TabSection(children=(BrowserCheck(), HBox(children=(Tab(closable=False, title='correlations', _dom_classes=('b…

# %%
bam.plot(df, 'in person?', 'more_distracted_at_home?')
# Out:
# TabSection(children=(BrowserCheck(), HBox(children=(Tab(closable=False, title='plot', _dom_classes=('bamboolib…

# %%
bam.plot(df, 'in person?', 'labs?')
# Out:
# TabSection(children=(BrowserCheck(), HBox(children=(Tab(closable=False, title='plot', _dom_classes=('bamboolib…

# %%
# Out:
#    in person?                       major labs?  num_of_units easy_internet?  \
# 0          No                        Math   Yes         14.00             No
# 1         Yes  Humanities/Social Sciences    No         12.00            Yes
# 2          No                     Science   Yes         18.00            Yes
# 3         Yes           Engineering/CS/DS   Yes         14.00            Yes
# 4         Yes           Engineering/CS/DS    No         20.00            Yes
# 5         Yes                        Math    No         16.00            Yes
# 6         Yes  Humanities/Social Sciences    No         21.50             No
# 7         Yes                     Science   Yes         22.00            Yes
# 8          No           Engineering/CS/DS   Yes         12.50            Yes
# 9         Yes           Engineering/CS/DS   Yes         16.00            Yes
# 10         No           Engineering/CS/DS   Yes         20.00            Yes
# 11         No           Engineering/CS/DS   Yes         21.50            Yes
# 12         No           Engineering/CS/DS   Yes         20.00            Yes
# 13        Yes           Engineering/CS/DS    No          9.67            Yes
# 14         No           Engineering/CS/DS   Yes         14.00            Yes
# 15         No                     Science   Yes         12.00            Yes
# 16         No  Humanities/Social Sciences   Yes          9.00            Yes
# 17         No  Humanities/Social Sciences    No         12.00            Yes
# 18         No           Engineering/CS/DS   Yes         12.00            Yes
# 19         No  Humanities/Social Sciences    No         14.00            Yes
# 20         No                     Science   Yes         18.00            Yes
# 21         No                     Science   Yes         12.00            Yes
# 22        Yes                        Math    No         12.00            Yes
# 23        Yes           Engineering/CS/DS   Yes         15.00            Yes
# 24         No                     Science   Yes         12.00            Yes
# 25         No                     Science   Yes         14.00            Yes
# 26         No           Engineering/CS/DS   Yes         13.00            Yes
# 27         No  Humanities/Social Sciences    No         12.00            Yes
# 28         No                     Science   Yes         14.00            Yes
# 29         No           Engineering/CS/DS    No         16.00            Yes
# 30         No           Engineering/CS/DS   Yes         10.50            Yes
# 31         No  Humanities/Social Sciences    No         12.00            Yes
# 32         No  Humanities/Social Sciences   Yes         11.00            Yes
# 33         No                     Science   Yes          0.00            Yes
# 34         No  Humanities/Social Sciences    No         20.50            Yes
# 35        Yes           Engineering/CS/DS   Yes          4.00            Yes
# 36         No           Engineering/CS/DS    No          6.00            Yes
# 37        Yes  Humanities/Social Sciences    No         13.00            Yes
# 38        Yes  Humanities/Social Sciences   Yes          8.00            Yes
# 39         No                     Science   Yes          7.00            Yes
# 40         No  Humanities/Social Sciences   Yes          8.00            Yes
# 41        Yes                     Science   Yes          6.00            Yes
# 42         No                     Science   Yes         14.00            Yes
# 43         No           Engineering/CS/DS   Yes         20.00            Yes
# 44         No  Humanities/Social Sciences    No         12.00            Yes
# 45         No                     Science   Yes         14.00            Yes
# 46         No                     Science   Yes         14.00            Yes
# 47         No                     Science   Yes          6.00            Yes
# 48         No  Humanities/Social Sciences    No         12.00            Yes
#
#     max_screentime more_distracted_at_home?  commute_time_mins  \
# 0              130                      Yes                 34
# 1               40                      Yes                 35
# 2              180                       No                 20
# 3              240                      Yes                 41
# 4              240                      Yes                 25
# 5               20                      Yes                 15
# 6              250                      Yes                 30
# 7              600                      Yes                 20
# 8              480                       No                 40
# 9              120                       No                 20
# 10             960                       No                120
# 11             960                       No                180
# 12             120                       No                 20
# 13             600                       No                 60
# 14              10                      Yes                 90
# 15            1080                       No                 90
# 16               3                       No                 10
# 17             240                      Yes                 15
# 18             120                      Yes                 15
# 19              60                      Yes                 30
# 20             700                       No                960
# 21             180                       No                240
# 22              60                      Yes                 20
# 23             300                      Yes                 20
# 24            1080                       No                 40
# 25             120                       No                 10
# 26              90                      Yes                 10
# 27             500                       No                 20
# 28             120                       No                 30
# 29             300                       No                 43
# 30             600                      Yes                 20
# 31             180                      Yes                 15
# 32             360                       No                 15
# 33              30                      Yes                 60
# 34             180                       No                 15
# 35              60                      Yes                 30
# 36             120                      Yes                 20
# 37             400                      Yes                 25
# 38              60                      Yes                 20
# 39             120                       No                 45
# 40             480                      Yes                 25
# 41              60                       No                 20
# 42             120                       No                 10
# 43             120                      Yes                 30
# 44             120                      Yes                 20
# 45             210                       No                 15
# 46             120                       No                 10
# 47             600                      Yes                 75
# 48             120                      Yes                 20
#
#     personality_rating  in person?_label  major_label  labs?_label  \
# 0                    2                 0            0            0
# 1                    4                 1            1            1
# 2                    1                 0            2            0
# 3                    3                 1            3            0
# 4                    2                 1            3            1
# 5                    3                 1            0            1
# 6                    2                 1            1            1
# 7                    2                 1            2            0
# 8                    3                 0            3            0
# 9                    2                 1            3            0
# 10                   2                 0            3            0
# 11                   1                 0            3            0
# 12                   3                 0            3            0
# 13                   2                 1            3            1
# 14                   3                 0            3            0
# 15                   2                 0            2            0
# 16                   3                 0            1            0
# 17                   3                 0            1            1
# 18                   4                 0            3            0
# 19                   3                 0            1            1
# 20                   4                 0            2            0
# 21                   4                 0            2            0
# 22                   2                 1            0            1
# 23                   3                 1            3            0
# 24                   2                 0            2            0
# 25                   1                 0            2            0
# 26                   3                 0            3            0
# 27                   1                 0            1            1
# 28                   5                 0            2            0
# 29                   2                 0            3            1
# 30                   2                 0            3            0
# 31                   1                 0            1            1
# 32                   2                 0            1            0
# 33                   3                 0            2            0
# 34                   3                 0            1            1
# 35                   3                 1            3            0
# 36                   3                 0            3            1
# 37                   3                 1            1            1
# 38                   3                 1            1            0
# 39                   4                 0            2            0
# 40                   1                 0            1            0
# 41                   3                 1            2            0
# 42                   1                 0            2            0
# 43                   2                 0            3            0
# 44                   4                 0            1            1
# 45                   1                 0            2            0
# 46                   1                 0            2            0
# 47                   3                 0            2            0
# 48                   1                 0            1            1
#
#     easy_internet?_label  more_distracted_at_home?_label
# 0                      0                               0
# 1                      1                               0
# 2                      1                               1
# 3                      1                               0
# 4                      1                               0
# 5                      1                               0
# 6                      0                               0
# 7                      1                               0
# 8                      1                               1
# 9                      1                               1
# 10                     1                               1
# 11                     1                               1
# 12                     1                               1
# 13                     1                               1
# 14                     1                               0
# 15                     1                               1
# 16                     1                               1
# 17                     1                               0
# 18                     1                               0
# 19                     1                               0
# 20                     1                               1
# 21                     1                               1
# 22                     1                               0
# 23                     1                               0
# 24                     1                               1
# 25                     1                               1
# 26                     1                               0
# 27                     1                               1
# 28                     1                               1
# 29                     1                               1
# 30                     1                               0
# 31                     1                               0
# 32                     1                               1
# 33                     1                               0
# 34                     1                               1
# 35                     1                               0
# 36                     1                               0
# 37                     1                               0
# 38                     1                               0
# 39                     1                               1
# 40                     1                               0
# 41                     1                               1
# 42                     1                               1
# 43                     1                               0
# 44                     1                               0
# 45                     1                               1
# 46                     1                               1
# 47                     1                               0
# 48                     1                               0
